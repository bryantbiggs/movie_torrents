# %%
print(1)
# Out:
# 1

# %%
import requests
from bs4 import BeautifulSoup
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-7-7601acf5f47d> in <module>()
# ----> 1 import requests
#       2 from bs4 import BeautifulSoup
#
# ImportError: No module named 'requests'
